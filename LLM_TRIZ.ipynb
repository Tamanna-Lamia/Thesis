# %%
pip install pandas numpy faiss-cpu sentence-transformers
# Out:
# Requirement already satisfied: pandas in c:\users\israh\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy in c:\users\israh\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: faiss-cpu in c:\users\israh\anaconda3\lib\site-packages (1.10.0)
# Requirement already satisfied: sentence-transformers in c:\users\israh\anaconda3\lib\site-packages (4.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\israh\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\israh\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\israh\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: packaging in c:\users\israh\anaconda3\lib\site-packages (from faiss-cpu) (23.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\israh\anaconda3\lib\site-packages (from sentence-transformers) (4.51.1)
# Requirement already satisfied: tqdm in c:\users\israh\anaconda3\lib\site-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\israh\anaconda3\lib\site-packages (from sentence-transformers) (2.6.0)
# Requirement already satisfied: scikit-learn in c:\users\israh\anaconda3\lib\site-packages (from sentence-transformers) (1.3.0)
# Requirement already satisfied: scipy in c:\users\israh\anaconda3\lib\site-packages (from sentence-transformers) (1.11.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\israh\anaconda3\lib\site-packages (from sentence-transformers) (0.30.2)
# Requirement already satisfied: Pillow in c:\users\israh\anaconda3\lib\site-packages (from sentence-transformers) (10.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\israh\anaconda3\lib\site-packages (from sentence-transformers) (4.13.1)
# Requirement already satisfied: filelock in c:\users\israh\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\israh\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\israh\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0)
# Requirement already satisfied: requests in c:\users\israh\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: six>=1.5 in c:\users\israh\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: networkx in c:\users\israh\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in c:\users\israh\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: sympy==1.13.1 in c:\users\israh\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\israh\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\israh\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\israh\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2022.7.9)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\israh\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\israh\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\israh\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\israh\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\israh\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\israh\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\israh\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\israh\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\israh\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.7.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import faiss
from sentence_transformers import SentenceTransformer

# %% [markdown]
# # Load LLM model

# %%
model = SentenceTransformer("patent/sbert-all-MiniLM-L6-v2")

# %% [markdown]
# # Load patent dataset

# %%
patent_df = pd.read_excel(r"C:\Users\israh\Desktop\Masters\THESIS\code\Patent_database\patent500.xlsx")
print(patent_df.head())
# Out:
#    patent_id                                    patent_abstract
# 0   10000000  A frequency modulated (coherent) laser detecti...
# 1   10000001  The injection molding machine includes a fixed...
# 2   10000002  The present invention relates to: a method for...
# 3   10000003  The invention relates to a method for producin...
# 4   10000004  The present invention relates to provides a do...

# %% [markdown]
# # Load TRIZ dataset

# %%
triz_df = pd.read_csv(r"C:\Users\israh\Desktop\Masters\THESIS\code\TRIZ_effects_database\combined_triz_dataset.csv")
print(triz_df.head())
# Out:
#         tag input_1_name input_1_value input_2_name  input_2_value  \
# 0  Function       action        Absorb       object  Divided Solid
# 1  Function       action        Absorb       object  Divided Solid
# 2  Function       action        Absorb       object  Divided Solid
# 3  Function       action        Absorb       object  Divided Solid
# 4  Function       action        Absorb       object  Divided Solid
#
#               result                                        description
# 0  Activated Alumina  A manufactured form of alumina (aluminium oxid...
# 1   Activated Carbon  (or activated charcoal, activated coal, carbo ...
# 2           Adhesive  A compound that adheres or bonds two items tog...
# 3           Aerogels  A manufactured material with the lowest bulk d...
# 4        Amphiphiles  A chemical compound possessing both hydrophili...

# %% [markdown]
# # Embed patent + Build FAISS Index

# %%
print("Embedding patent database...")
patent_embeddings = model.encode(patent_df["patent_abstract"].tolist(), convert_to_numpy=True)
print("Embedding patent database: done")
#Build FAISS index for Patents
print("Building FAISS index for patents...")
patent_dim = patent_embeddings.shape[1]
patent_index = faiss.IndexFlatL2(patent_dim)
patent_index.add(patent_embeddings)

print("Building FAISS index: done")
# Out:
# Embedding patent database...
# Embedding patent database: done
# Building FAISS index for patents...
# Building FAISS index: done

# %% [markdown]
# # view embedding in table

# %%
# Convert embeddings to DataFrame
embedding_df = pd.DataFrame(patent_embeddings)

# Add metadata
embedding_df['patent_id'] = patent_df['patent_id']
embedding_df['abstract'] = patent_df['patent_abstract']

# Show first few rows
embedding_df.head(3)
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.106439  0.231193  0.028058 -0.023522 -0.426877  0.121179 -0.106983
# 1 -0.331230  0.331754  0.000149  0.156075 -0.423781  0.225393  0.040836
# 2 -0.393579  0.277757  0.115055 -0.034416 -0.423899  0.083583 -0.071407
#
#           7         8         9  ...       376       377       378       379  \
# 0  0.105149 -0.267921  0.125781  ... -0.049630 -0.288474  0.069247 -0.018643
# 1  0.230348 -0.485862  0.271967  ... -0.032981 -0.257741  0.033413 -0.131023
# 2  0.384509 -0.444063  0.316631  ...  0.013390 -0.328412  0.125423  0.069547
#
#         380       381       382       383  patent_id  \
# 0  0.225912 -0.039725 -0.074736  0.014816   10000000
# 1  0.120830  0.136021 -0.052865  0.087452   10000001
# 2  0.270139  0.030074  0.081338  0.256067   10000002
#
#                                             abstract
# 0  A frequency modulated (coherent) laser detecti...
# 1  The injection molding machine includes a fixed...
# 2  The present invention relates to: a method for...
#
# [3 rows x 386 columns]

# %% [markdown]
# # Embed TRIZ + Build FAISS Index

# %%
print("Embedding TRIZ effects...")

triz_texts = (
    triz_df["input_1_name"].fillna('') + " " +
    triz_df["input_1_value"].fillna('') + " " +
    triz_df["input_2_name"].fillna('') + " " +
    triz_df["input_2_value"].fillna('') + " " +
    triz_df["result"].fillna('') + " " +
    triz_df["description"].fillna('') + " " +
    triz_df["tag"].fillna('')
).tolist()

triz_embeddings = model.encode(triz_texts, convert_to_numpy=True)
print("Embedding TRIZ database: done")

#Build FAISS index for TRIZ
print("Building FAISS index for TRIZ...")
triz_dim = triz_embeddings.shape[1]
triz_index = faiss.IndexFlatL2(triz_dim)
triz_index.add(triz_embeddings)

print("Building FAISS index: done")
# Out:
# Embedding TRIZ effects...
# Embedding TRIZ database: done
# Building FAISS index for TRIZ...
# Building FAISS index: done

# %% [markdown]
# # TRIZ Functions

# %%
def expand_query_with_triz(query, model, triz_index, triz_df, top_k=1):
    """Expand the user query using the most semantically similar TRIZ principle."""
    query_embedding = model.encode([query], convert_to_numpy=True)
    distances, indices = triz_index.search(query_embedding, top_k)
    
    # Get best matching TRIZ effect
    top_triz = triz_df.iloc[indices[0][0]]

    # ---- Build full TRIZ description dynamically ----
    triz_description = (
        str(top_triz.get("input_1_name", "")) + " " +
        str(top_triz.get("input_1_value", "")) + " " +
        str(top_triz.get("input_2_name", "")) + " " +
        str(top_triz.get("input_2_value", "")) + " " +
        str(top_triz.get("result", "")) + " " +
        str(top_triz.get("description", "")) + " " +
        str(top_triz.get("tag", ""))
    )

    # Expand the query
    enhanced_query = query + " " + triz_description
    print(f"\nExpanded Query with TRIZ:\n{enhanced_query}\n")
    return enhanced_query


def search_patents_with_triz(query, top_k=5, return_expanded_query=False):
    triz_expanded_query = expand_query_with_triz(query, model, triz_index, triz_df, top_k=1)
    results = search_patents_no_triz(triz_expanded_query, top_k=top_k)
    
    if return_expanded_query:
        return results, triz_expanded_query
    return results

# %% [markdown]
# # Normal Patent Search (No TRIZ)

# %%
def search_patents_no_triz(query, top_k=5):
    """Search patents without TRIZ expansion."""
    query_embedding = model.encode([query], convert_to_numpy=True)
    distances, indices = patent_index.search(query_embedding, top_k)
    results = patent_df.iloc[indices[0]]
    return results[["patent_id", "patent_abstract"]]

# %% [markdown]
# # Query here

# %%
import os

output_file = "combined_patent_search_results_rows.csv"

while True:
    user_query = input("\nEnter your patent search query (or type 'exit' to quit): ").strip()
    if user_query.lower() == 'exit':
        print("Exiting search.")
        break

    print("\n--- Searching without TRIZ expansion ---")
    normal_results = search_patents_no_triz(user_query, top_k=5)
    print(normal_results)

    print("\n--- Searching WITH TRIZ expansion ---")
    triz_results, triz_expanded_query = search_patents_with_triz(user_query, top_k=5, return_expanded_query=True)
    print(triz_results)

    # Add metadata columns
    normal_results["query"] = user_query
    normal_results["source"] = "LLM"
    normal_results["expanded_query"] = user_query

    triz_results["query"] = user_query
    triz_results["source"] = "TRIZ"
    triz_results["expanded_query"] = triz_expanded_query

    # Combine and reorder
    combined = pd.concat([normal_results, triz_results], ignore_index=True)
    combined = combined[["query", "source", "expanded_query", "patent_id", "patent_abstract"]]

    # Append to CSV
    if os.path.exists(output_file):
        combined.to_csv(output_file, mode='a', header=False, index=False)
    else:
        combined.to_csv(output_file, index=False)

    print(f"Results for '{user_query}' saved to '{output_file}'.")
# Out:
# Enter your patent search query (or type 'exit' to quit): 3-D printing system
#
# --- Searching without TRIZ expansion ---
#      patent_id                                    patent_abstract
# 54    10000056  A screen printing apparatus includes a pair of...
# 10    10000010  3-D printing system include development statio...
# 349   10000353  A sheet flipping device includes a receiving m...
# 22    10000024  An apparatus for controlling 3D printing inclu...
# 320   10000324  In a packing bag to store a stored article Z w...
#
# --- Searching WITH TRIZ expansion ---
#
# Expanded Query with TRIZ:
# 3-D printing system operation Measure parameter Shape 3D Printing The process of creating three dimensional objects from digital data using a materials printer, in a manner similar to printing images on paper. The term is most closely associated with additive manufacturing technology, where an object is created by laying down successive layers of material. Parameter
#
#      patent_id                                    patent_abstract
# 22    10000024  An apparatus for controlling 3D printing inclu...
# 54    10000056  A screen printing apparatus includes a pair of...
# 19    10000021  There is provided a method for manufacturing a...
# 63    10000065  An inkjet printing system includes an ink rese...
# 302   10000306  Disclosed are container apparatuses that have ...
# Results for '3-D printing system' saved to 'combined_patent_search_results_rows.csv'.
#
# Enter your patent search query (or type 'exit' to quit): ink cartridge for writing instrument
#
# --- Searching without TRIZ expansion ---
#      patent_id                                    patent_abstract
# 65    10000067  Ink includes water, an organic solvent, a surf...
# 85    10000088  A writing instrument includes: a replacement i...
# 460   10000467  Compounds used as labels with properties compa...
# 54    10000056  A screen printing apparatus includes a pair of...
# 86    10000089  A multi-color writing marker may comprise a tu...
#
# --- Searching WITH TRIZ expansion ---
#
# Expanded Query with TRIZ:
# ink cartridge for writing instrument operation Decrease parameter Porosity Sol A colloidal suspension of solid particles (1-500 nanometres in size) in a liquid. Examples include blood, pigmented ink, and paint. Parameter
#
#      patent_id                                    patent_abstract
# 414   10000419  Compositions and methods associated with inter...
# 302   10000306  Disclosed are container apparatuses that have ...
# 421   10000426  A composition for allowing marking of a produc...
# 78    10000081  There is provided a transfer sheet with improv...
# 66    10000068  A controller changes a droplet number larger t...
# Results for 'ink cartridge for writing instrument' saved to 'combined_patent_search_results_rows.csv'.
#
# Enter your patent search query (or type 'exit' to quit): device to measure tire pressure
#
# --- Searching without TRIZ expansion ---
#      patent_id                                    patent_abstract
# 97    10000100  Systems and methods of determining tire load f...
# 87    10000090  The present invention provides a pneumatic rad...
# 209   10000213  A pressure of a spare tire of a vehicle is det...
# 95    10000098  Embodiments provide a tire pressure measuremen...
# 96    10000099  The invention relates to a tire pressure monit...
#
# --- Searching WITH TRIZ expansion ---
#
# Expanded Query with TRIZ:
# device to measure tire pressure operation Measure parameter Pressure Electromechanical Film A thin membrane whose thickness is related to an electric voltage. It can be used as a pressure sensor, microphone, or a speaker. It can also convert electrical energy to vibration, functioning as an actuator. Parameter
#
#      patent_id                                    patent_abstract
# 97    10000100  Systems and methods of determining tire load f...
# 87    10000090  The present invention provides a pneumatic rad...
# 227   10000231  An apparatus for applying an auxiliary force i...
# 134   10000137  A sub DC/DC converter converts an output volta...
# 95    10000098  Embodiments provide a tire pressure measuremen...
# Results for 'device to measure tire pressure' saved to 'combined_patent_search_results_rows.csv'.
#
# Enter your patent search query (or type 'exit' to quit): underwater vehicle
#
# --- Searching without TRIZ expansion ---
#      patent_id                                    patent_abstract
# 262   10000266  An aquatic jet propulsion device basically inc...
# 261   10000265  An underwater vehicle may include a buoyancy c...
# 240   10000244  A vehicle with a manual controlled hydrostatic...
# 280   10000284  The disclosed unmanned aerial vehicle (UAV) in...
# 87    10000090  The present invention provides a pneumatic rad...
#
# --- Searching WITH TRIZ expansion ---
#
# Expanded Query with TRIZ:
# underwater vehicle action Separate object Solid Aquaplaning A phenonomen that occurs when a layer of water builds between the wheels of the vehicle and the road surface, leading to a loss of traction that prevents the vehicle from responding to control inputs. Function
#
#      patent_id                                    patent_abstract
# 261   10000265  An underwater vehicle may include a buoyancy c...
# 163   10000166  An arrangement for a motor vehicle including a...
# 284   10000288  A laterally and recline adjustable aircraft pa...
# 255   10000259  A suction anchor for a remotely operated vehic...
# 240   10000244  A vehicle with a manual controlled hydrostatic...
# Results for 'underwater vehicle' saved to 'combined_patent_search_results_rows.csv'.
#
# Enter your patent search query (or type 'exit' to quit): thermally insulated container
#
# --- Searching without TRIZ expansion ---
#      patent_id                                    patent_abstract
# 404   10000409  Alkali-doped boroaluminosilicate glasses are p...
# 4     10000004  The present invention relates to provides a do...
# 428   10000433  The invention describes a high yield process t...
# 44    10000046  Methods of creating thick composite structures...
# 366   10000370  Methods and apparatus describing a convenience...
#
# --- Searching WITH TRIZ expansion ---
#
# Expanded Query with TRIZ:
# thermally insulated container action Cool object Gas Rayleigh-Bénard Convection Convection cells that appear spontaneously in a liquid layer when heat is applied from below. Function
#
#      patent_id                                    patent_abstract
# 4     10000004  The present invention relates to provides a do...
# 11    10000011  To reduce distortion in an additively manufact...
# 406   10000411  The invention provides flash-treated transpare...
# 40    10000042  The current disclosure relates to a polymeric ...
# 78    10000081  There is provided a transfer sheet with improv...
# Results for 'thermally insulated container' saved to 'combined_patent_search_results_rows.csv'.
#
# Enter your patent search query (or type 'exit' to quit): automated warehouse storage system
#
# --- Searching without TRIZ expansion ---
#      patent_id                                    patent_abstract
# 156   10000159  A storage bin system is provided for a motor v...
# 280   10000284  The disclosed unmanned aerial vehicle (UAV) in...
# 155   10000158  A bag for storing and holding electronic and n...
# 220   10000224  The invention relates to a method and handling...
# 336   10000340  A vented bucket for use in an endless conveyor...
#
# --- Searching WITH TRIZ expansion ---
#
# Expanded Query with TRIZ:
# automated warehouse storage system operation Stabilise parameter Position Close Packing A dense arrangement of equal spheres in an infinite, regular arrangement (or lattice). There are two simple regular lattices that achieve highest average density: face-centered cubic (also called cubic close packed) and hexagonal close-packed. Both are based upon sheets of spheres arranged at the vertices of a triangular tiling; they differ in how the sheets are stacked upon one another. Parameter
#
#      patent_id                                    patent_abstract
# 342   10000346  A transport element for a distributing conveyo...
# 302   10000306  Disclosed are container apparatuses that have ...
# 282   10000286  An aircraft storage bin that includes an upper...
# 284   10000288  A laterally and recline adjustable aircraft pa...
# 223   10000227  A cylindrical buckling prevention member is fi...
# Results for 'automated warehouse storage system' saved to 'combined_patent_search_results_rows.csv'.
# Enter your patent search query (or type 'exit' to quit): power supply wire
#
# --- Searching without TRIZ expansion ---
#      patent_id                                    patent_abstract
# 164   10000167  A wire harness includes a cable unit, and an i...
# 126   10000129  A vehicle includes an engine, a traction batte...
# 292   10000296  An example aircraft electrical system includes...
# 361   10000365  An improved pulley for winch is described, in ...
# 281   10000285  Described herein are methods and systems for d...
#
# --- Searching WITH TRIZ expansion ---
#
# Expanded Query with TRIZ:
# power supply wire operation Measure parameter Power Ampère's Force Law Ampere's Force Law decribes the force of attraction or repulsion between two current-carrying wires. Parameter
#
#      patent_id                                    patent_abstract
# 278   10000282  An aircraft landing gear assembly includes a m...
# 223   10000227  A cylindrical buckling prevention member is fi...
# 97    10000100  Systems and methods of determining tire load f...
# 284   10000288  A laterally and recline adjustable aircraft pa...
# 188   10000192  An electro-mechanical brake for increasing a b...
# Results for 'power supply wire' saved to 'combined_patent_search_results_rows.csv'.
#
# Enter your patent search query (or type 'exit' to quit): glucose deprivation in cancer treatment
#
# --- Searching without TRIZ expansion ---
#      patent_id                                    patent_abstract
# 436   10000443  Glucose deprivation is an attractive strategy ...
# 471   10000478  This application features pyrazol-3-one compou...
# 493   10000501  The present invention concerns a compound of f...
# 466   10000473  The present invention is directed to indazole ...
# 467   10000474  Provided herein are compounds of the formula (...
#
# --- Searching WITH TRIZ expansion ---
#
# Expanded Query with TRIZ:
# glucose deprivation in cancer treatment action Remove object Divided Solid Enzyme Proteins that catalyze (i.e., increase the rates of) chemical reactions. Almost all chemical reactions in a biological cell need enzymes in order to occur at rates sufficient for life. Enzymes differ from most other catalysts in that they are highly specific for their substrates Function
#
#      patent_id                                    patent_abstract
# 476   10000483  The present invention provides novel compounds...
# 436   10000443  Glucose deprivation is an attractive strategy ...
# 479   10000487  The present invention provides synthesis, phar...
# 475   10000482  The present invention relates to novel compoun...
# 452   10000459  Heterocyclic compounds are described that are ...
# Results for 'glucose deprivation in cancer treatment' saved to 'combined_patent_search_results_rows.csv'.
#
# Enter your patent search query (or type 'exit' to quit): heat sealing machine
#
# --- Searching without TRIZ expansion ---
#      patent_id                                    patent_abstract
# 4     10000004  The present invention relates to provides a do...
# 306   10000310  A pull-tab sealing member for a container cont...
# 44    10000046  Methods of creating thick composite structures...
# 366   10000370  Methods and apparatus describing a convenience...
# 397   10000401  In accordance with the present invention, prob...
#
# --- Searching WITH TRIZ expansion ---
#
# Expanded Query with TRIZ:
# heat sealing machine operation Increase parameter Heat Conduction Archimedes Screw A device with a revolving screw-shaped blade inside a cylinder that can be used for pumping liquids and semifluid solids such as coal and grain. Parameter
#
#      patent_id                                    patent_abstract
# 223   10000227  A cylindrical buckling prevention member is fi...
# 4     10000004  The present invention relates to provides a do...
# 188   10000192  An electro-mechanical brake for increasing a b...
# 1     10000001  The injection molding machine includes a fixed...
# 178   10000182  In a buckle device, displacement of a buckle c...
# Results for 'heat sealing machine' saved to 'combined_patent_search_results_rows.csv'.
#
# Enter your patent search query (or type 'exit' to quit): infant stroller
#
# --- Searching without TRIZ expansion ---
#      patent_id                                    patent_abstract
# 222   10000226  An infant stroller apparatus includes a first ...
# 221   10000225  A mobile child support and entertainment devic...
# 284   10000288  A laterally and recline adjustable aircraft pa...
# 174   10000178  A vehicle curtain airbag device that includes:...
# 242   10000246  A vehicle comprises a front spoiler with at le...
#
# --- Searching WITH TRIZ expansion ---
#
# Expanded Query with TRIZ:
# infant stroller action Separate object Divided Solid Coffee Ring Effect A pattern left by a puddle of particle-laden liquid after it evaporates. Named after the characteristic ring-like deposit along the perimeter of a spill of coffee. The pattern is due to capillary flow induced by the differential evaporation rates across the drop: liquid evaporating from the edge is replenished by liquid from the interior. The resulting edgeward flow can carry nearly all the dispersed material to the edge. Function
#
#      patent_id                                    patent_abstract
# 284   10000288  A laterally and recline adjustable aircraft pa...
# 312   10000316  A collapsible container is provided with a one...
# 288   10000292  An evacuation system may comprise an evacuatio...
# 223   10000227  A cylindrical buckling prevention member is fi...
# 109   10000112  A door assembly for a vehicle includes a door ...
# Results for 'infant stroller' saved to 'combined_patent_search_results_rows.csv'.
#
# Enter your patent search query (or type 'exit' to quit): Aircraft display systems
#
# --- Searching without TRIZ expansion ---
#      patent_id                                    patent_abstract
# 118   10000121  The invention relates to a vehicle computer sy...
# 271   10000275  An aircraft hybrid flight control system compr...
# 203   10000207  A vehicle hitch detection system is provided. ...
# 38    10000040  Floor panel of the type substantially consisti...
# 45    10000047  The present invention provides a method for ma...
#
# --- Searching WITH TRIZ expansion ---
#
# Expanded Query with TRIZ:
# Aircraft display systems operation Measure parameter Surface Area Image Processing Processing of images using mathematical operations by using any form of signal processing for which the input is an image, a series of images, or a video, such as a photograph or video frame The output of image processing may be either an image or a set of characteristics or parameters related to the image. Parameter
#
#      patent_id                                    patent_abstract
# 284   10000288  A laterally and recline adjustable aircraft pa...
# 271   10000275  An aircraft hybrid flight control system compr...
# 79    10000082  Described is a painting stamp having built-in ...
# 183   10000187  In the vehicle communication system provided w...
# 97    10000100  Systems and methods of determining tire load f...
# Results for 'Aircraft display systems' saved to 'combined_patent_search_results_rows.csv'.
#
# Enter your patent search query (or type 'exit' to quit): exit
# Exiting search.

# %% [markdown]
# # Semantic Similarity
# Get the semantic similarity score between query and result

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Load the saved search results
file_path = "combined_patent_search_results_rows.csv"
df = pd.read_csv(file_path)

# Load PatentBERT model
model = SentenceTransformer("patent/sbert-all-MiniLM-L6-v2")

def compute_similarity_from_csv(df, model):
    """Compute semantic similarity for each row in the DataFrame."""
    # Get query and abstract embeddings
    query_embeddings = model.encode(df["query"].tolist(), convert_to_numpy=True)
    abstract_embeddings = model.encode(df["patent_abstract"].tolist(), convert_to_numpy=True)

    # Compute cosine similarity row-wise
    similarities = []
    for q, a in zip(query_embeddings, abstract_embeddings):
        sim = cosine_similarity([q], [a])[0][0]
        similarities.append(sim)

    df["semantic_similarity"] = similarities
    return df

scored_df = compute_similarity_from_csv(df, model)
scored_df.to_csv("scored_patent_search_results.csv", index=False)
scored_df.head()
# Out:
#                  query source       expanded_query  patent_id  \
# 0  3-D printing system    LLM  3-D printing system   10000056
# 1  3-D printing system    LLM  3-D printing system   10000010
# 2  3-D printing system    LLM  3-D printing system   10000353
# 3  3-D printing system    LLM  3-D printing system   10000024
# 4  3-D printing system    LLM  3-D printing system   10000324
#
#                                      patent_abstract  semantic_similarity
# 0  A screen printing apparatus includes a pair of...             0.694970
# 1  3-D printing system include development statio...             0.686107
# 2  A sheet flipping device includes a receiving m...             0.670232
# 3  An apparatus for controlling 3D printing inclu...             0.659352
# 4  In a packing bag to store a stored article Z w...             0.637138
